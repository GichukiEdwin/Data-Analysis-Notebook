# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('us_counties_population_est_2019.csv')
df.head()
# Out:
#    state_fips  county_fips  region state_name     county_name   area_land  \
# 0           1            1       3    Alabama  Autauga County  1539602137
# 1           1            3       3    Alabama  Baldwin County  4117621645
# 2           1            5       3    Alabama  Barbour County  2292160139
# 3           1            7       3    Alabama     Bibb County  1612167476
# 4           1            9       3    Alabama   Blount County  1670103866
#
#    area_water  internal_point_lat  internal_point_lon  pop_est_2018  \
# 0    25706961           32.532237          -86.646439         55533
# 1  1132980868           30.659218          -87.746067        217855
# 2    50523213           31.870253          -85.405103         24872
# 3     9602089           33.015893          -87.127148         22367
# 4    15015467           33.977357          -86.566440         57771
#
#    pop_est_2019  births_2019  deaths_2019  international_migr_2019  \
# 0         55869          624          541                      -16
# 1        223234         2304         2326                       80
# 2         24686          256          312                       13
# 3         22394          240          252                       10
# 4         57826          651          657                        6
#
#    domestic_migr_2019  residual_2019
# 0                 270             -1
# 1                5297             24
# 2                -141             -2
# 3                  31             -2
# 4                  59             -4
