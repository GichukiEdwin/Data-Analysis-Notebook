# %%
import pandas as pd

# %%
names1880 = pd.read_csv('../datasets/names/yob1880.txt', names=['name', 'sex', 'births'])

# %%
names1880
# Out:
#            name sex  births
# 0          Mary   F    7065
# 1          Anna   F    2604
# 2          Emma   F    2003
# 3     Elizabeth   F    1939
# 4        Minnie   F    1746
# ...         ...  ..     ...
# 1995     Woodie   M       5
# 1996     Worthy   M       5
# 1997     Wright   M       5
# 1998       York   M       5
# 1999  Zachariah   M       5
#
# [2000 rows x 3 columns]
